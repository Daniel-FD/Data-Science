# %%
from sklearn.datasets import load_breast_cancer
from sklearn import preprocessing
import pandas as pd
from boruta import BorutaPy
from sklearn import ensemble
from sklearn import tree
import xgboost as xgb

# %%
# load the data trainging set
X, y = load_breast_cancer(return_X_y=True)
data = load_breast_cancer()

# %%
def Boruta(model, X, y):
    # define Boruta feature selection method
    feat_selector = BorutaPy(model, n_estimators='auto', verbose=2, random_state=1)
    # find all relevant features
    feat_selector.fit(X, y)
    # check selected features
    feat_selector.support_
    # check ranking of features
    feat_selector.ranking_
    # call transform() on X to filter it down to selected features
    X_filtered = feat_selector.transform(X)
    # 
    print('Boruta Algorithm Succesfully Completed')
    return X_filtered

# %% [markdown]
# # Random Forest Classifier

# %%
# define random forest classifier
model = ensemble.RandomForestClassifier()
model.fit(X, y)
X_filtered = Boruta(model, X, y)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	21
# Tentative: 	9
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	21
# Tentative: 	9
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	21
# Tentative: 	9
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	21
# Tentative: 	9
# Rejected: 	0
# Iteration: 	12 / 100
# Confirmed: 	21
# Tentative: 	9
# Rejected: 	0
# Iteration: 	13 / 100
# Confirmed: 	21
# Tentative: 	9
# Rejected: 	0
# Iteration: 	14 / 100
# Confirmed: 	21
# Tentative: 	9
# Rejected: 	0
# ...

# %%
# define random forest classifier
model = ensemble.RandomForestClassifier(n_jobs = -1)
model.fit(X, y)
X_filtered = Boruta(model, X, y)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	21
# Tentative: 	9
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	21
# Tentative: 	9
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	21
# Tentative: 	9
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	21
# Tentative: 	9
# Rejected: 	0
# Iteration: 	12 / 100
# Confirmed: 	21
# Tentative: 	9
# Rejected: 	0
# Iteration: 	13 / 100
# Confirmed: 	21
# Tentative: 	9
# Rejected: 	0
# Iteration: 	14 / 100
# Confirmed: 	21
# Tentative: 	9
# Rejected: 	0
# ...

# %% [markdown]
# # XGB Classifier

# %%
# define random forest classifier
model = xgb.XGBClassifier()
model.fit(X, y)
X_filtered = Boruta(model, X, y)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	9 / 100
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	10 / 100
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	11 / 100
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	12 / 100
# Confirmed: 	4
# Tentative: 	9
# Rejected: 	17
# Iteration: 	13 / 100
# Confirmed: 	4
# Tentative: 	9
# Rejected: 	17
# Iteration: 	14 / 100
# Confirmed: 	4
# Tentative: 	9
# Rejected: 	17
# ...

# %% [markdown]
# # Tree Classifier

# %%
# define tree classifier 
model = tree.DecisionTreeClassifier()
model = model.fit(X,y)
X_filtered = Boruta(model,X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/danielfiuzadosil/Documents/GitHub_Repo/Data-Science/Algorithms/Boruta_Feature_Selection/main.ipynb Cell 10 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/danielfiuzadosil/Documents/GitHub_Repo/Data-Science/Algorithms/Boruta_Feature_Selection/main.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> model2 = tree.DecisionTreeClassifier()
#       <a href='vscode-notebook-cell:/Users/danielfiuzadosil/Documents/GitHub_Repo/Data-Science/Algorithms/Boruta_Feature_Selection/main.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> model2 = model2.fit(X,y)
# ----> <a href='vscode-notebook-cell:/Users/danielfiuzadosil/Documents/GitHub_Repo/Data-Science/Algorithms/Boruta_Feature_Selection/main.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> X_filtered = Boruta(model2,X,y)
#
# ...

# %%
# define tree classifier 
model = tree.DecisionTreeClassifier(max_depth = 5)
model = model.fit(X,y)
X_filtered = Boruta(model, X, y)
