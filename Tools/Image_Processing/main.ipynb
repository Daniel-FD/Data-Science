# %%
import gradio as gr
import numpy as np
from numpy import asarray
import matplotlib.pyplot as plt
from f_measurements_check import measurements_checks

# %%
def check(img):
    img = measurements_checks(img)
    img_np = asarray(img)
    return img_np

# %%
img = measurements_checks('images/good/2.jpeg')
plt.imshow(img)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
demo = gr.Interface(
    fn = check,
    inputs = gr.Image(source="webcam", streaming=True), 
    outputs =  gr.Image(type="numpy"),
    examples = ['images/good/2.jpeg', 'images/good/1.jpeg']
)
# Out:
# IMPORTANT: You are using gradio version 3.3.1, however version 3.14.0 is available, please upgrade.
# --------

# %%
demo.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://c9a4b6d0f3230d0d.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://www.huggingface.co/spaces
# <div><iframe src="https://c9a4b6d0f3230d0d.gradio.app" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7fad4ab9d730>,
#  'http://127.0.0.1:7860/',
#  'https://c9a4b6d0f3230d0d.gradio.app')
# Traceback (most recent call last):
#   File "/Users/danielfiuzadosil/Documents/GitHub_Repo/Data-Science/Tools/Image_Processing/f_measurements_check.py", line 67, in measurements_checks
#     image = cv2.imread(image_0)
# TypeError: Can't convert object to 'str' for 'filename'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...
