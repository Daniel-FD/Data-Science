# %% [markdown]
# notes: to create a custom boundary I noticed that the boundary is not in regular cooridnates, instead:
# - (-8.40268 43.36968) --> (548393.678 4802042.219)
# This was caused by the library osmnx.projection.project_gdf
#
# Project a GeoDataFrame from its current CRS to another.

# %%
import prettymaps
import pprint
import geopandas as gpd
from shapely.geometry import Polygon
import osmnx as ox
# Out:
# /Users/danielfiuzadosil/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# **your_query** can be:
# 1. An address (Example: "Porto Alegre"),
# 2. Latitude / Longitude coordinates (Example: (-30.0324999, -51.2303767))
# 3. A custom boundary in GeoDataFrame format

# %%
lon_lat_list = [[ -8.433745660425185, 43.347331541948869 ], 
                [ -8.372057143421673, 43.347009482909961 ], 
                [ -8.371592516397957, 43.392029306070974 ], 
                [ -8.433326671648997, 43.392351869045932 ], 
                [ -8.433745660425185, 43.347331541948869 ]]

# %%
polygon_geom = Polygon(lon_lat_list)
polygon = gpd.GeoDataFrame(index=[0], crs='epsg:4326', geometry=[polygon_geom]) 
polygon.to_file(filename='polygon_input.geojson', driver='GeoJSON')

# %%
# lat_point_list = [43.3538, 43.3538, 43.3923,  43.3923]
# lon_point_list = [-8.37206, -8.43375, -8.43375, -8.37206]
# polygon_geom = Polygon(zip(lon_point_list, lat_point_list))
# polygon = gpd.GeoDataFrame(index=[0], crs='epsg:4326', geometry=[polygon_geom]) 
# with open('log_polygon.txt', 'w') as f:
#         f.write(str(polygon))  
# print(polygon)
# polygon_input = ox.project_gdf(polygon)
# print(polygon_input)
# polygon_input = polygon_input.to_crs(4326)
# print(polygon_input)

# %%
lon_lat_list[0][0]
# Out:
# -8.433745660425185

# %%
import folium
m = folium.Map([lon_lat_list[0][1], lon_lat_list[0][0]], zoom_start=12, tiles='cartodbpositron')
folium.GeoJson(polygon).add_to(m)
folium.LatLngPopup().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
plot = prettymaps.plot(polygon)
# Out:
# radius in get_perimeter  500
# here, parsequery, polygon
# here, parsequery, polygon
# Here!!!! We have given a perimeter
#                                             geometry
# 0  POLYGON ((-8.43375 43.34733, -8.37206 43.34701...
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.

# %%
# Coruña
query_coordinates = (43.3696847569242, -8.402680497973337)
plot = prettymaps.plot(query_coordinates, radius = 2500) # radius = 500 works
# Out:
# radius in get_perimeter  2500
# query (43.3696847569242, -8.402680497973337)
# radius 2500
# parse_query coordinates
# coordinate_modified_v1 (-8.402680497973337, 43.3696847569242)
# coordinate_modified_v2 POINT (-8.402680497973337 43.3696847569242)
# coordinate_modified_v3                     geometry
# 0  POINT (-8.40268 43.36968)
# coordinate_modified_v4                          geometry
# 0  POINT (548393.678 4802042.219)
# coordinate_modified_v5                          geometry
# 0  POINT (548393.678 4802042.219)
# x position square:  548393.6776954561
# y position square:  4802042.219467215
# boundary square:                                              geometry
# 0  POLYGON ((545893.678 4799542.219, 550893.678 4...
#                                             geometry
# 0  POLYGON ((545893.678 4799542.219, 550893.678 4...
# <class 'geopandas.geodataframe.GeoDataFrame'>
# final boundary:                                             geometry
# ...

# %%
stop!

# %%
plot = prettymaps.plot("Vitoria", radius = 2500)
import matplotlib.pyplot as plt
plt.gca().set_position([0, 0, 1, 1])
plt.savefig("output/test.svg")
# Out:
# radius in get_perimeter  2500
# query Vitoria
# radius 2500
# parse_query address
# coordinate_modified_v1 (-2.6724025, 42.8465088)
# coordinate_modified_v2 POINT (-2.6724025 42.8465088)
# coordinate_modified_v3                     geometry
# 0  POINT (-2.67240 42.84651)
# coordinate_modified_v4                          geometry
# 0  POINT (526768.312 4743822.130)
# coordinate_modified_v5                          geometry
# 0  POINT (526768.312 4743822.130)
# x position square:  526768.3124915407
# y position square:  4743822.129557262
# boundary square:                                              geometry
# 0  POLYGON ((524268.312 4741322.130, 529268.312 4...
#                                             geometry
# 0  POLYGON ((524268.312 4741322.130, 529268.312 4...
# <class 'geopandas.geodataframe.GeoDataFrame'>
# final boundary:                                             geometry
# 0  POLYGON ((-2.70311 42.82408, -2.64194 42.82390...
# ...

# %%
plot = prettymaps.plot("Vitoria, Pais Vasco", radius = 1000)
import matplotlib.pyplot as plt
plt.gca().set_position([0, 0, 1, 1])
plt.savefig("output/test_vitoria.svg")
# Out:
# radius in get_perimeter  1000
# query Vitoria, Pais Vasco
# radius 1000
# parse_query address
# coordinate_modified_v1 (-2.6724025, 42.8465088)
# coordinate_modified_v2 POINT (-2.6724025 42.8465088)
# coordinate_modified_v3                     geometry
# 0  POINT (-2.67240 42.84651)
# coordinate_modified_v4                          geometry
# 0  POINT (526768.312 4743822.130)
# coordinate_modified_v5                          geometry
# 0  POINT (526768.312 4743822.130)
# x position square:  526768.3124915407
# y position square:  4743822.129557262
# boundary square:                                              geometry
# 0  POLYGON ((525768.312 4742822.130, 527768.312 4...
#                                             geometry
# 0  POLYGON ((525768.312 4742822.130, 527768.312 4...
# <class 'geopandas.geodataframe.GeoDataFrame'>
# final boundary:                                             geometry
# 0  POLYGON ((-2.68469 42.83754, -2.66021 42.83747...
# ...

# %%
plot = prettymaps.plot("Miranda de Ebro")
# Out:
# radius in get_perimeter  500
# query Miranda de Ebro
# radius 500
# parse_query address
# coordinate_modified_v1 (-2.9478451, 42.6855632)
# coordinate_modified_v2 POINT (-2.9478451 42.6855632)
# coordinate_modified_v3                     geometry
# 0  POINT (-2.94785 42.68556)
# coordinate_modified_v4                          geometry
# 0  POINT (504272.673 4725899.405)
# coordinate_modified_v5                          geometry
# 0  POINT (504272.673 4725899.405)
# x position square:  504272.6725693806
# y position square:  4725899.405182251
# boundary square:                                              geometry
# 0  POLYGON ((503772.673 4725399.405, 504772.673 4...
#                                             geometry
# 0  POLYGON ((503772.673 4725399.405, 504772.673 4...
# <class 'geopandas.geodataframe.GeoDataFrame'>
# final boundary:                                             geometry
# 0  POLYGON ((-2.95395 42.68106, -2.94175 42.68106...
# ...
