# %%
# !promptfoo eval --output results.json
# Out:
# (node:61889) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
#
# ...
# ⚠️ The current version of promptfoo 0.89.2 is lower than the latest available version 0.89.4.
#
# Please run npx promptfoo@latest or npm install -g promptfoo@latest to update.
# ...
#
# [░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░] 0% | ETA: 0s | 0/9 |  ""
# [░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░] 0% | ETA: 0s | 0/9 |  ""
# [░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░] 0% | ETA: 0s | 0/9 |  ""
# [░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░] 0% | ETA: 0s | 0/9 |  ""
#
#
# [████░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░] 11% | ETA: 3s | 1/9 | ollama:completion:llama3.1 "def simple" animal_sta
# [████░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░] 11% | ETA: 3s | 1/9 | ollama:completion:llama3.1 "def simple" animal_sta
# ...

# %%
# !promptfoo eval --output results.csv
# Out:
# (node:61973) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
#
# ...
# ⚠️ The current version of promptfoo 0.89.2 is lower than the latest available version 0.89.4.
#
# Please run npx promptfoo@latest or npm install -g promptfoo@latest to update.
# ...
#
# [░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░] 0% | ETA: 0s | 0/9 |  ""
# [░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░] 0% | ETA: 0s | 0/9 |  ""
# [░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░] 0% | ETA: 0s | 0/9 |  ""
# [░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░] 0% | ETA: 0s | 0/9 |  ""
#
#
#
#
#
#
#
#
# [████░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░] 11% | ETA: 4s | 1/9 | ollama:completion:llama3.1 "def simple" animal_sta
# [████░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░] 11% | ETA: 4s | 1/9 | ollama:completion:llama3.1 "def simple" animal_sta
# ...
