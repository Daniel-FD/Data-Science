# %%
from optimize_prompt import optimize_prompt
import pandas as pd

# %%
# Initial prompt for classification
initial_prompt = (
    "You are a sentiment analysis classifier. Determine whether the provided text expresses a positive sentiment."
)

# Output format prompt
output_format_prompt = (
    "You are to respond strictly in binary format. For each question, reply only with '1' for positive or '0' for negative. "
    "Do not include any other text, explanations, or comments."
)

# %%
# Number of optimization iterations
iterations = 10 # You can adjust this value

# %%
# Load and preprocess the evaluation dataset
eval_data = pd.read_csv('reviews.csv', encoding='ISO-8859-1', usecols=['Text', 'Sentiment'])
eval_data.columns = ['text', 'label']
# Randomly select 50 positive and 50 negative samples, combine without shuffling
eval_data = (
    eval_data.groupby('label')
    .apply(lambda x: x.sample(n=10, random_state=42))
    .reset_index(drop=True)
)
# Sort the DataFrame to ensure incremental index
eval_data = eval_data.sort_index()

# %%
# Start the prompt optimization process
optimize_prompt(initial_prompt, output_format_prompt, eval_data, iterations)
# Out:
# Iteration 1/10
# ╭─────────────────────────────── System Prompt ────────────────────────────────╮
# │                                                                              │
# │ You are a sentiment analysis classifier. Determine whether the provided text │
# │ expresses a positive sentiment.  You are to respond strictly in binary       │
# │ format. For each question, reply only with '1' for positive or '0' for       │
# │ negative. Do not include any other text, explanations, or comments.          │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Processing text 1/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 2/20
# Prediction: 0 | Ground Truth: 0 ✅ (TN)
# Processing text 3/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 4/20
# Prediction: 0 | Ground Truth: 0 ✅ (TN)
# Processing text 5/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 6/20
# Prediction: 0 | Ground Truth: 0 ✅ (TN)
# Processing text 7/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 8/20
# Prediction: 0 | Ground Truth: 0 ✅ (TN)
# Processing text 9/20
# Prediction: 0 | Ground Truth: 0 ✅ (TN)
# Processing text 10/20
# Prediction: 0 | Ground Truth: 0 ✅ (TN)
# Processing text 11/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 12/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 13/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 14/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 15/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 16/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 17/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 18/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 19/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 20/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
#
# Number of invalid predictions: 0
# Evaluation Metrics - Iteration 1
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃ Metric              ┃  Value ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │ Precision           │ 0.7143 │
# │ Recall              │ 1.0000 │
# │ Accuracy            │ 0.8000 │
# │ F1-score            │ 0.8333 │
# │ Invalid Predictions │      0 │
# └─────────────────────┴────────┘
# Analyzing misclassifications...
# ╭──────────────────────────────────────── Analysis of Misclassifications ─────────────────────────────────────────╮
# │                                                                                                                 │
# │ After analyzing the misclassifications, I've identified some common patterns and provided insights into why     │
# │ these errors occurred.                                                                                          │
# │                                                                                                                 │
# │ **Negative (0) texts (incorrectly classified as positive)**                                                     │
# │                                                                                                                 │
# │ 1. **"Shuttle" review**: This review is actually a negative one, but the model incorrectly classified it as     │
# │ positive because of phrases like "I think even God would say, 'Good call.'" and "'Shuttle' was a decent film."  │
# │ The model seems to have focused on these isolated positive statements rather than considering the overall tone  │
# │ and content of the review.                                                                                      │
# │                                                                                                                 │
# │ Why this error occurred: The model may be too sensitive to individual sentences or phrases that contain         │
# │ positive words, without taking into account the context in which they are used. This can lead to false          │
# │ positives when the text is actually negative but contains some redeeming qualities.                             │
# │                                                                                                                 │
# │ 2. **"Dragon Hunt" review**: Despite calling it "one of the cheapest action flicks of the eighties," this       │
# │ reviewer still enjoys watching it as a guilty pleasure or party tape. The model may have misinterpreted the     │
# │ tone, thinking that the reviewer's enthusiasm for the movie's absurdity means they genuinely enjoy it.          │
# │                                                                                                                 │
# │ Why this error occurred: The model might be too quick to classify texts based on surface-level positive         │
# │ statements without considering the nuances of tone and intent. In this case, the reviewer is being facetious or │
# │ ironic when praising the movie.                                                                                 │
# │                                                                                                                 │
# │ 3. **"What the World Needs to Know About Islam" review**: This scathing review highlights the film's poor       │
# │ production values and lack of journalistic integrity. The model should have classified it as a negative review  │
# │ based on its harsh language.                                                                                    │
# │                                                                                                                 │
# │ Why this error occurred: The model may be too focused on identifying obvious positive or negative keywords,     │
# │ without considering the overall sentiment and impact of the text.                                               │
# │                                                                                                                 │
# │ 4. **"Clonus" review**: This reviewer calls the film "mediocre" and "crappy," but mentions that it's better     │
# │ than some other films they've seen on MST3K. The model incorrectly classified this as a positive review because │
# │ of the mention of MST3K, which is often associated with humorous or entertaining content.                       │
# │                                                                                                                 │
# │ Why this error occurred: The model may be too influenced by external associations or biases, rather than        │
# │ evaluating the text based on its inherent value and sentiment.                                                  │
# │                                                                                                                 │
# │ Correct classifications for these examples:                                                                     │
# │                                                                                                                 │
# │ * "Shuttle" review: Negative                                                                                    │
# │ * "Dragon Hunt" review: Negative (with a hint of irony or sarcasm)                                              │
# │ * "What the World Needs to Know About Islam" review: Negative                                                   │
# │ * "Clonus" review: Negative                                                                                     │
# │                                                                                                                 │
# │ **Strategies to improve the classification prompt**                                                             │
# │                                                                                                                 │
# │ 1. **Contextualize individual statements**: Train the model to consider the overall context and tone of the     │
# │ text, rather than focusing solely on individual sentences or phrases.                                           │
# │ 2. **Account for nuances in tone and intent**: Develop strategies to detect irony, sarcasm, or other forms of   │
# │ nuanced language that can be misinterpreted by simple keyword-based approaches.                                 │
# │ 3. **Increase sensitivity to subtle differences**: Tune the model to recognize smaller-scale variations in      │
# │ sentiment and classification, rather than relying on binary thresholds.                                         │
# │ 4. **Reduce external bias and associations**: Implement techniques to mitigate biases stemming from external    │
# │ factors, such as cultural or contextual influences.                                                             │
# │ 5. **Consider a more granular classification framework**: Instead of relying solely on positive/negative        │
# │ labels, consider implementing a multi-classification system that accounts for degrees of sentiment (e.g.,       │
# │ negative, neutral, positive).                                                                                   │
# │                                                                                                                 │
# │ By addressing these issues and incorporating the recommended strategies, you can improve the accuracy of your   │
# │ LLM model's binary classifications.                                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Generating new prompt...
# ╭───────────────────────────────────────────── Prompt Engineer Input ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │         You are an expert in crafting highly effective prompts. Your task is to help me improve a prompt for    │
# │ binary classification. I will give you the current prompt and an analysis showing where it failed to classify a │
# │ piece of text correctly. Your goal is to refine the prompt to be more precise and adaptable, ensuring that the  │
# │ AI can accurately classify similar texts going forward. The revised prompt should be written in the first       │
# │ person, guiding the AI to handle difficult or edge cases.                                                       │
# │                                                                                                                 │
# │         Current prompt:                                                                                         │
# │         You are a sentiment analysis classifier. Determine whether the provided text expresses a positive       │
# │ sentiment.                                                                                                      │
# │                                                                                                                 │
# │         Analysis of misclassifications:                                                                         │
# │         After analyzing the misclassifications, I've identified some common patterns and provided insights into │
# │ why these errors occurred.                                                                                      │
# │                                                                                                                 │
# │ **Negative (0) texts (incorrectly classified as positive)**                                                     │
# │                                                                                                                 │
# │ 1. **"Shuttle" review**: This review is actually a negative one, but the model incorrectly classified it as     │
# │ positive because of phrases like "I think even God would say, 'Good call.'" and "'Shuttle' was a decent film."  │
# │ The model seems to have focused on these isolated positive statements rather than considering the overall tone  │
# │ and content of the review.                                                                                      │
# │                                                                                                                 │
# │ Why this error occurred: The model may be too sensitive to individual sentences or phrases that contain         │
# │ positive words, without taking into account the context in which they are used. This can lead to false          │
# │ positives when the text is actually negative but contains some redeeming qualities.                             │
# │                                                                                                                 │
# │ 2. **"Dragon Hunt" review**: Despite calling it "one of the cheapest action flicks of the eighties," this       │
# │ reviewer still enjoys watching it as a guilty pleasure or party tape. The model may have misinterpreted the     │
# │ tone, thinking that the reviewer's enthusiasm for the movie's absurdity means they genuinely enjoy it.          │
# │                                                                                                                 │
# │ Why this error occurred: The model might be too quick to classify texts based on surface-level positive         │
# │ statements without considering the nuances of tone and intent. In this case, the reviewer is being facetious or │
# │ ironic when praising the movie.                                                                                 │
# │                                                                                                                 │
# │ 3. **"What the World Needs to Know About Islam" review**: This scathing review highlights the film's poor       │
# │ production values and lack of journalistic integrity. The model should have classified it as a negative review  │
# │ based on its harsh language.                                                                                    │
# │                                                                                                                 │
# │ Why this error occurred: The model may be too focused on identifying obvious positive or negative keywords,     │
# │ without considering the overall sentiment and impact of the text.                                               │
# │                                                                                                                 │
# │ 4. **"Clonus" review**: This reviewer calls the film "mediocre" and "crappy," but mentions that it's better     │
# │ than some other films they've seen on MST3K. The model incorrectly classified this as a positive review because │
# │ of the mention of MST3K, which is often associated with humorous or entertaining content.                       │
# │                                                                                                                 │
# │ Why this error occurred: The model may be too influenced by external associations or biases, rather than        │
# │ evaluating the text based on its inherent value and sentiment.                                                  │
# │                                                                                                                 │
# │ Correct classifications for these examples:                                                                     │
# │                                                                                                                 │
# │ * "Shuttle" review: Negative                                                                                    │
# │ * "Dragon Hunt" review: Negative (with a hint of irony or sarcasm)                                              │
# │ * "What the World Needs to Know About Islam" review: Negative                                                   │
# │ * "Clonus" review: Negative                                                                                     │
# │                                                                                                                 │
# │ **Strategies to improve the classification prompt**                                                             │
# │                                                                                                                 │
# │ 1. **Contextualize individual statements**: Train the model to consider the overall context and tone of the     │
# │ text, rather than focusing solely on individual sentences or phrases.                                           │
# │ 2. **Account for nuances in tone and intent**: Develop strategies to detect irony, sarcasm, or other forms of   │
# │ nuanced language that can be misinterpreted by simple keyword-based approaches.                                 │
# │ 3. **Increase sensitivity to subtle differences**: Tune the model to recognize smaller-scale variations in      │
# │ sentiment and classification, rather than relying on binary thresholds.                                         │
# │ 4. **Reduce external bias and associations**: Implement techniques to mitigate biases stemming from external    │
# │ factors, such as cultural or contextual influences.                                                             │
# │ 5. **Consider a more granular classification framework**: Instead of relying solely on positive/negative        │
# │ labels, consider implementing a multi-classification system that accounts for degrees of sentiment (e.g.,       │
# │ negative, neutral, positive).                                                                                   │
# │                                                                                                                 │
# │ By addressing these issues and incorporating the recommended strategies, you can improve the accuracy of your   │
# │ LLM model's binary classifications.                                                                             │
# │                                                                                                                 │
# │         Your task is to provide a rewritten, production-ready version of the prompt that improves its accuracy. │
# │                                                                                                                 │
# │         IMPORTANT note: the prompt should not include any preamble or request for explanations, just the final  │
# │ prompt itself.                                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Iteration 2/10
# ╭─────────────────────────────── System Prompt ───────────────────────────────╮
# │                                                                             │
# │ Here is the rewritten prompt:  "I'm a nuanced sentiment analyzer. I'll      │
# │ carefully consider the overall tone and context of the provided text to     │
# │ determine whether it expresses a predominantly positive or negative         │
# │ sentiment, acknowledging subtle variations in language and avoiding biases  │
# │ stemming from external associations. I'll also be sensitive to nuances like │
# │ irony, sarcasm, or humor that can influence my interpretation."  You are to │
# │ respond strictly in binary format. For each question, reply only with '1'   │
# │ for positive or '0' for negative. Do not include any other text,            │
# │ explanations, or comments.                                                  │
# │                                                                             │
# ╰─────────────────────────────────────────────────────────────────────────────╯
# Processing text 1/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 2/20
# Prediction: 1
# 0
# 0
# 1
# 0
# 1
# 0
# 0
# 1
# 0 | Ground Truth: 0 🛠️ (Invalid Output Format)
# Processing text 3/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 4/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 5/20
# Prediction: 0 | Ground Truth: 0 ✅ (TN)
# Processing text 6/20
# Prediction: 0 | Ground Truth: 0 ✅ (TN)
# Processing text 7/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 8/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 9/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 10/20
# Prediction: 0 | Ground Truth: 0 ✅ (TN)
# Processing text 11/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 12/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 13/20
# Prediction: 1101010001011000110110101101110010010111001011101010 | Ground Truth: 1 🛠️ (Invalid Output Format)
# Processing text 14/20
# Prediction: 0 | Ground Truth: 1 ❌ (FN)
# Processing text 15/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 16/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 17/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 18/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 19/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 20/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
#
# Number of invalid predictions: 2
# Evaluation Metrics - Iteration 2
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃ Metric              ┃  Value ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │ Precision           │ 0.5000 │
# │ Recall              │ 0.8750 │
# │ Accuracy            │ 0.5556 │
# │ F1-score            │ 0.6364 │
# │ Invalid Predictions │      2 │
# └─────────────────────┴────────┘
# Analyzing misclassifications...
# ╭──────────────────────────────────────── Analysis of Misclassifications ─────────────────────────────────────────╮
# │                                                                                                                 │
# │ **Analysis**                                                                                                    │
# │                                                                                                                 │
# │ The LLM model misclassified several texts as either positive or negative, when in fact they belonged to the     │
# │ opposite category. By examining each example, we can identify specific elements that may have led to these      │
# │ errors.                                                                                                         │
# │                                                                                                                 │
# │ **False Positives (Incorrectly classified as Positive)**                                                        │
# │                                                                                                                 │
# │ 1. **"Avoid this bomb like it will infect you with an STD."**: This text was incorrectly classified as a        │
# │ positive review.                                                                                                │
# │         * Why: The model likely focused on the phrase "a 5'2 105 lb woman of course has the strength to kill    │
# │ men and women twice her size without a struggle and in a single blow" which could be seen as humorous or        │
# │ satirical, rather than criticizing the movie's writing.                                                         │
# │         * Correct Classification: Negative review                                                               │
# │ 2. **"What starts out as a passable movie degenerates into one of the most incoherent, UNscary, incompetently   │
# │ made, stupid attempted horror films of recent years."**: This text was incorrectly classified as a positive     │
# │ review.                                                                                                         │
# │         * Why: The model may have missed the strong negative adjectives used to describe the movie, such as     │
# │ "incoherent", "UNscary", and "incompetently made".                                                              │
# │         * Correct Classification: Negative review                                                               │
# │ 3. **"As a writer I find films this bad making it into production a complete slap in the face."**: This text    │
# │ was incorrectly classified as a positive review.                                                                │
# │         * Why: The model may have focused on the phrase "making it into production a complete slap in the       │
# │ face", which could be seen as a neutral or even slightly positive sentiment, rather than the overall negative   │
# │ tone of the text.                                                                                               │
# │         * Correct Classification: Negative review                                                               │
# │                                                                                                                 │
# │ **False Negatives (Incorrectly classified as Negative)**                                                        │
# │                                                                                                                 │
# │ 1. **"The idea ia a very short film with a lot of information."**: This text was incorrectly classified as a    │
# │ negative review.                                                                                                │
# │         * Why: The model likely focused on the phrase "a very short film with a lot of information", which      │
# │ could be seen as a positive aspect, rather than criticizing the movie's quality or impact.                      │
# │         * Correct Classification: Positive review                                                               │
# │ 2. **"The producer has produced a short film of excellent quality that cannot be compared to any other short    │
# │ film that I have seen."**: This text was incorrectly classified as a negative review.                           │
# │         * Why: The model may have missed the strong positive adjectives used to describe the movie, such as     │
# │ "excellent quality".                                                                                            │
# │         * Correct Classification: Positive review                                                               │
# │                                                                                                                 │
# │ **Insights and Recommendations**                                                                                │
# │                                                                                                                 │
# │ The errors in classification highlight several challenges with the current prompt:                              │
# │                                                                                                                 │
# │ 1. **Limited contextual understanding**: The model struggles to understand the nuances of context, leading to   │
# │ misinterpretation of phrases or sentences.                                                                      │
# │ 2. **Lack of subtlety recognition**: The model may not be able to recognize subtle differences between positive │
# │ and negative sentiments, especially when they are presented in a complex or humorous manner.                    │
# │ 3. **Insufficient emphasis on negative adjectives**: The model may focus too heavily on positive language,      │
# │ ignoring or downplaying negative adjectives that can indicate a negative review.                                │
# │                                                                                                                 │
# │ To improve the classification prompt and reduce both false positives and false negatives, we recommend the      │
# │ following strategies:                                                                                           │
# │                                                                                                                 │
# │ 1. **Increase contextual understanding**: Implement techniques such as named entity recognition (NER),          │
# │ part-of-speech tagging, or dependency parsing to better understand the context in which words and phrases are   │
# │ used.                                                                                                           │
# │ 2. **Improve subtlety recognition**: Train the model to recognize subtle differences between positive and       │
# │ negative sentiments, especially when they are presented in a complex or humorous manner.                        │
# │ 3. **Emphasize negative adjectives**: Place more emphasis on recognizing and analyzing negative adjectives,     │
# │ such as "incoherent", "UNscary", or "incompetently made".                                                       │
# │ 4. **Enhance sentiment analysis**: Implement advanced sentiment analysis techniques, such as aspect-based       │
# │ sentiment analysis or emotion recognition, to better capture the nuances of human sentiment.                    │
# │ 5. **Fine-tune the prompt**: Adjust the classification prompt to focus more on specific aspects that contribute │
# │ to a positive or negative review, rather than relying solely on general sentiment analysis.                     │
# │                                                                                                                 │
# │ By addressing these challenges and implementing the recommended strategies, we can improve the accuracy of text │
# │ classification and provide users with more reliable information about movie reviews.                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Generating new prompt...
# ╭───────────────────────────────────────────── Prompt Engineer Input ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │         You are an expert in crafting highly effective prompts. Your task is to help me improve a prompt for    │
# │ binary classification. I will give you the current prompt and an analysis showing where it failed to classify a │
# │ piece of text correctly. Your goal is to refine the prompt to be more precise and adaptable, ensuring that the  │
# │ AI can accurately classify similar texts going forward. The revised prompt should be written in the first       │
# │ person, guiding the AI to handle difficult or edge cases.                                                       │
# │                                                                                                                 │
# │         Current prompt:                                                                                         │
# │         Here is the rewritten prompt:                                                                           │
# │                                                                                                                 │
# │ "I'm a nuanced sentiment analyzer. I'll carefully consider the overall tone and context of the provided text to │
# │ determine whether it expresses a predominantly positive or negative sentiment, acknowledging subtle variations  │
# │ in language and avoiding biases stemming from external associations. I'll also be sensitive to nuances like     │
# │ irony, sarcasm, or humor that can influence my interpretation."                                                 │
# │                                                                                                                 │
# │         Analysis of misclassifications:                                                                         │
# │         **Analysis**                                                                                            │
# │                                                                                                                 │
# │ The LLM model misclassified several texts as either positive or negative, when in fact they belonged to the     │
# │ opposite category. By examining each example, we can identify specific elements that may have led to these      │
# │ errors.                                                                                                         │
# │                                                                                                                 │
# │ **False Positives (Incorrectly classified as Positive)**                                                        │
# │                                                                                                                 │
# │ 1. **"Avoid this bomb like it will infect you with an STD."**: This text was incorrectly classified as a        │
# │ positive review.                                                                                                │
# │         * Why: The model likely focused on the phrase "a 5'2 105 lb woman of course has the strength to kill    │
# │ men and women twice her size without a struggle and in a single blow" which could be seen as humorous or        │
# │ satirical, rather than criticizing the movie's writing.                                                         │
# │         * Correct Classification: Negative review                                                               │
# │ 2. **"What starts out as a passable movie degenerates into one of the most incoherent, UNscary, incompetently   │
# │ made, stupid attempted horror films of recent years."**: This text was incorrectly classified as a positive     │
# │ review.                                                                                                         │
# │         * Why: The model may have missed the strong negative adjectives used to describe the movie, such as     │
# │ "incoherent", "UNscary", and "incompetently made".                                                              │
# │         * Correct Classification: Negative review                                                               │
# │ 3. **"As a writer I find films this bad making it into production a complete slap in the face."**: This text    │
# │ was incorrectly classified as a positive review.                                                                │
# │         * Why: The model may have focused on the phrase "making it into production a complete slap in the       │
# │ face", which could be seen as a neutral or even slightly positive sentiment, rather than the overall negative   │
# │ tone of the text.                                                                                               │
# │         * Correct Classification: Negative review                                                               │
# │                                                                                                                 │
# │ **False Negatives (Incorrectly classified as Negative)**                                                        │
# │                                                                                                                 │
# │ 1. **"The idea ia a very short film with a lot of information."**: This text was incorrectly classified as a    │
# │ negative review.                                                                                                │
# │         * Why: The model likely focused on the phrase "a very short film with a lot of information", which      │
# │ could be seen as a positive aspect, rather than criticizing the movie's quality or impact.                      │
# │         * Correct Classification: Positive review                                                               │
# │ 2. **"The producer has produced a short film of excellent quality that cannot be compared to any other short    │
# │ film that I have seen."**: This text was incorrectly classified as a negative review.                           │
# │         * Why: The model may have missed the strong positive adjectives used to describe the movie, such as     │
# │ "excellent quality".                                                                                            │
# │         * Correct Classification: Positive review                                                               │
# │                                                                                                                 │
# │ **Insights and Recommendations**                                                                                │
# │                                                                                                                 │
# │ The errors in classification highlight several challenges with the current prompt:                              │
# │                                                                                                                 │
# │ 1. **Limited contextual understanding**: The model struggles to understand the nuances of context, leading to   │
# │ misinterpretation of phrases or sentences.                                                                      │
# │ 2. **Lack of subtlety recognition**: The model may not be able to recognize subtle differences between positive │
# │ and negative sentiments, especially when they are presented in a complex or humorous manner.                    │
# │ 3. **Insufficient emphasis on negative adjectives**: The model may focus too heavily on positive language,      │
# │ ignoring or downplaying negative adjectives that can indicate a negative review.                                │
# │                                                                                                                 │
# │ To improve the classification prompt and reduce both false positives and false negatives, we recommend the      │
# │ following strategies:                                                                                           │
# │                                                                                                                 │
# │ 1. **Increase contextual understanding**: Implement techniques such as named entity recognition (NER),          │
# │ part-of-speech tagging, or dependency parsing to better understand the context in which words and phrases are   │
# │ used.                                                                                                           │
# │ 2. **Improve subtlety recognition**: Train the model to recognize subtle differences between positive and       │
# │ negative sentiments, especially when they are presented in a complex or humorous manner.                        │
# │ 3. **Emphasize negative adjectives**: Place more emphasis on recognizing and analyzing negative adjectives,     │
# │ such as "incoherent", "UNscary", or "incompetently made".                                                       │
# │ 4. **Enhance sentiment analysis**: Implement advanced sentiment analysis techniques, such as aspect-based       │
# │ sentiment analysis or emotion recognition, to better capture the nuances of human sentiment.                    │
# │ 5. **Fine-tune the prompt**: Adjust the classification prompt to focus more on specific aspects that contribute │
# │ to a positive or negative review, rather than relying solely on general sentiment analysis.                     │
# │                                                                                                                 │
# │ By addressing these challenges and implementing the recommended strategies, we can improve the accuracy of text │
# │ classification and provide users with more reliable information about movie reviews.                            │
# │                                                                                                                 │
# │         Your task is to provide a rewritten, production-ready version of the prompt that improves its accuracy. │
# │                                                                                                                 │
# │         IMPORTANT note: the prompt should not include any preamble or request for explanations, just the final  │
# │ prompt itself.                                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Iteration 3/10
# ╭─────────────────────────────── System Prompt ────────────────────────────────╮
# │                                                                              │
# │ Here's the revised prompt:  "I'm a nuanced sentiment analyzer. I'll          │
# │ carefully consider the entire context and content of the provided text to    │
# │ determine whether it expresses a predominantly positive or negative          │
# │ sentiment. When detecting irony, sarcasm, humor, or other forms of subtle    │
# │ expression, I'll analyze these nuances in depth, taking care not to be       │
# │ swayed by external associations or biases. In evaluating sentiment, I'll     │
# │ give equal weight to both positive and negative adjectives, ensuring that    │
# │ the presence of strong negative descriptors like 'incoherent', 'UNscary', or │
# │ 'incompetently made' doesn't get overshadowed by seemingly neutral or        │
# │ positive phrases. My analysis will prioritize the overall tone and context,  │
# │ providing an accurate classification even in cases where subtle variations   │
# │ in language may challenge me."  You are to respond strictly in binary        │
# │ format. For each question, reply only with '1' for positive or '0' for       │
# │ negative. Do not include any other text, explanations, or comments.          │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Processing text 1/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 2/20
# Prediction: 0 | Ground Truth: 0 ✅ (TN)
# Processing text 3/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 4/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 5/20
# Prediction: 0 | Ground Truth: 0 ✅ (TN)
# Processing text 6/20
# Prediction: 0 | Ground Truth: 0 ✅ (TN)
# Processing text 7/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 8/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 9/20
# Prediction: 1 | Ground Truth: 0 ❌ (FP)
# Processing text 10/20
# Prediction: 0 | Ground Truth: 0 ✅ (TN)
# Processing text 11/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 12/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 13/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 14/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 15/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 16/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 17/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 18/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 19/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
# Processing text 20/20
# Prediction: 1 | Ground Truth: 1 ✅ (TP)
#
# Number of invalid predictions: 0
# Evaluation Metrics - Iteration 3
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃ Metric              ┃  Value ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │ Precision           │ 0.6250 │
# │ Recall              │ 1.0000 │
# │ Accuracy            │ 0.7000 │
# │ F1-score            │ 0.7692 │
# │ Invalid Predictions │      0 │
# └─────────────────────┴────────┘
# Analyzing misclassifications...
# ╭──────────────────────────────────────── Analysis of Misclassifications ─────────────────────────────────────────╮
# │                                                                                                                 │
# │ After analyzing the misclassifications, I've identified several patterns and insights that can help improve the │
# │ classification prompt.                                                                                          │
# │                                                                                                                 │
# │ **Negative (0) texts incorrectly classified as positive:**                                                      │
# │                                                                                                                 │
# │ 1. **"Shuttle" review**: The reviewer uses strong language, such as "hate," but also mentions enjoying aspects  │
# │ of the film, like its realism and some good shocks. This mixed tone might have led the model to misinterpret    │
# │ the overall sentiment.                                                                                          │
# │         * Correct classification: Negative (0)                                                                  │
# │ 2. **"Dragon Hunt" review**: Although the reviewer calls it a "great party tape," they also state that the      │
# │ movie is "really awful." The focus on its entertainment value as a trashy film might have confused the model.   │
# │         * Correct classification: Negative (0)                                                                  │
# │ 3. **Dillinger biopic review**: Despite the reviewer's strong criticism, they mention some redeeming qualities, │
# │ like the action and acting. However, their overall assessment is decidedly negative.                            │
# │         * Correct classification: Negative (0)                                                                  │
# │ 4. **"Clonus" review**: The reviewer savages the film, calling it a "mediocre, low-budget flick" with poor      │
# │ writing and acting. Their tone is consistently negative.                                                        │
# │         * Correct classification: Negative (0)                                                                  │
# │ 5. **Script review**: The writer's scathing assessment of the script might have been misinterpreted as          │
# │ sarcastic or ironic, leading to an incorrect positive classification.                                           │
# │         * Correct classification: Negative (0)                                                                  │
# │ 6. **"Heart of Darkness" review**: Although the reviewer criticizes the movie for its lack of detail and        │
# │ schizophrenic plot line, they also mention its connection to Joseph Conrad's book. This context might have led  │
# │ the model to misinterpret the sentiment as generally positive.                                                  │
# │         * Correct classification: Negative (0)                                                                  │
# │                                                                                                                 │
# │ **Common themes and insights:**                                                                                 │
# │                                                                                                                 │
# │ 1. **Mixed tone**: Some reviews contain mixed sentiments, making it challenging for the model to determine the  │
# │ overall tone.                                                                                                   │
# │ 2. **Contextualization**: Reviews may reference external contexts or comparisons that influence the reader's    │
# ...
# │ This misclassification likely resulted from the prompt's tendency to focus on the reviewer's initial enthusiasm │
# │ rather than their overall tone.                                                                                 │
# │                                                                                                                 │
# │ Correct classification: **Negative**                                                                            │
# │                                                                                                                 │
# │ **3. Heart of Darkness (Positive → Negative)**                                                                  │
# │ The review starts by criticizing the movie for leaving out important scenes and themes from the book, implying  │
# │ a negative sentiment towards both the book and movie. However, the tone shifts to a more critical analysis of   │
# │ the movie's shortcomings in capturing the book's essence. The reviewer concludes with an invitation to read the │
# │ book, which could be interpreted as a positive recommendation, but given the context, it seems to be a          │
# │ constructive critique rather than an endorsement.                                                               │
# │                                                                                                                 │
# │ Correct classification: **Negative**                                                                            │
# │                                                                                                                 │
# │ **4. Generic Horror Movie (Positive → Negative)**                                                               │
# │ The review is overwhelmingly negative, calling the movie "derivative," "incoherent," and lacking any scares or  │
# │ tension. The tone remains consistently critical throughout, with no redeeming qualities mentioned. This         │
# │ misclassification likely resulted from the prompt's sensitivity to the reviewer's tone, which was initially     │
# │ unclear but ultimately confirmed as strongly negative.                                                          │
# │                                                                                                                 │
# │ Correct classification: **Negative**                                                                            │
# │                                                                                                                 │
# │ Strategies to improve the classification prompt:                                                                │
# │                                                                                                                 │
# │ 1. **Tone analysis**: Consider adding more nuanced tone-based features that can better capture the subtleties   │
# │ of sentiment in reviews. This might include tracking shifts in tone or sentiment throughout a review.           │
# │ 2. **Contextual understanding**: Improve the model's ability to understand context by incorporating techniques  │
# │ like coreference resolution, entity recognition, and discourse analysis. This will help the model better grasp  │
# │ the relationships between statements and identify when a positive or negative sentiment is actually             │
# │ constructive or critical.                                                                                       │
# │ 3. **Sentiment granulation**: Implement more granular sentiment classification (e.g., Strong Negative, Weak     │
# │ Positive, Constructive Criticism) to capture subtle differences in tone that might have led to                  │
# │ misclassifications.                                                                                             │
# │ 4. **Review-specific features**: Consider adding review-specific features like "movie-related criticism" or     │
# │ "book-related discussion" to help the model distinguish between reviews that discuss a movie and those that     │
# │ discuss a book.                                                                                                 │
# │                                                                                                                 │
# │ By implementing these strategies, we can reduce both false positives (e.g., Classifying Clonus as Positive) and │
# │ false negatives (e.g., Classifying Heart of Darkness as Negative for the movie), improving overall              │
# │ classification accuracy.                                                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Generating new prompt...
# ╭───────────────────────────────────────────── Prompt Engineer Input ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │         You are an expert in crafting highly effective prompts. Your task is to help me improve a prompt for    │
# │ binary classification. I will give you the current prompt and an analysis showing where it failed to classify a │
# │ piece of text correctly. Your goal is to refine the prompt to be more precise and adaptable, ensuring that the  │
# │ AI can accurately classify similar texts going forward. The revised prompt should be written in the first       │
# │ person, guiding the AI to handle difficult or edge cases.                                                       │
# │                                                                                                                 │
# │         Current prompt:                                                                                         │
# │         Here's the revised prompt:                                                                              │
# │                                                                                                                 │
# │ "I'm a nuanced sentiment analyzer. I'll carefully consider the entire context and content of the provided text  │
# │ to determine whether it expresses a predominantly positive, negative, neutral/critical, or mixed sentiment.     │
# │ When detecting irony, sarcasm, humor, or other forms of subtle expression, I'll analyze these nuances in depth, │
# │ taking care not to be swayed by external associations or biases. My analysis will prioritize the overall tone   │
# │ and context, even when faced with mixed sentiments or contextual influences that might challenge me.            │
# │                                                                                                                 │
# │ I'll recognize and account for idiomatic expressions, nuanced language use, and subtle differences between      │
# │ neutral, critical, and strong negative reviews. I'll also differentiate between frustration and scathing        │
# │ criticism, and avoid over-classifying reviews as strong negatives due to isolated words or phrases.             │
# │                                                                                                                 │
# │ In cases where strong negative descriptors coexist with seemingly neutral or positive phrases, I'll give equal  │
# │ weight to both, ensuring a balanced evaluation of the sentiment. When highlighting specific issues with a movie │
# │ or book, I'll classify the review as neutral/critical rather than solely negative.                              │
# │                                                                                                                 │
# │ My classification will focus on the overall tone and context, taking into account any comparisons or references │
# │ to other works that may impact my assessment. If a review contains both positive and negative statements, I'll  │
# │ consider it as a mixed sentiment."                                                                              │
# │                                                                                                                 │
# │         Analysis of misclassifications:                                                                         │
# │         Analysis of misclassifications:                                                                         │
# │                                                                                                                 │
# │ **1. Heart of Darkness (Negative → Positive)**                                                                  │
# │ The original review starts with a scathing critique, calling the movie "incoherent," "unscary," and             │
# │ "incompetently made." However, as it progresses, the tone shifts to a more nuanced discussion of the book's     │
# │ themes and the movie's failure to capture them. The reviewer concludes by advising readers who have not read    │
# │ the book to skip the movie, which implies a positive classification towards the book but not the movie. This    │
# │ misclassification likely resulted from the prompt's sensitivity to the reviewer's tone, which was initially     │
# │ negative but ultimately more constructive.                                                                      │
# │                                                                                                                 │
# │ Correct classification: **Negative** (for the movie), **Positive** (for the book)                               │
# │                                                                                                                 │
# │ **2. Clonus (Positive → Negative)**                                                                             │
# │ The initial review is glowing, praising the MST3K version as "priceless" and awarding four stars to the film.   │
# │ However, it devolves into a scathing critique of the movie's production values, writing, acting, and directing. │
# │ The reviewer concludes with a warning to avoid the movie like an STD, indicating a strong negative sentiment.   │
# │ This misclassification likely resulted from the prompt's tendency to focus on the reviewer's initial enthusiasm │
# │ rather than their overall tone.                                                                                 │
# │                                                                                                                 │
# │ Correct classification: **Negative**                                                                            │
# │                                                                                                                 │
# │ **3. Heart of Darkness (Positive → Negative)**                                                                  │
# │ The review starts by criticizing the movie for leaving out important scenes and themes from the book, implying  │
# │ a negative sentiment towards both the book and movie. However, the tone shifts to a more critical analysis of   │
# │ the movie's shortcomings in capturing the book's essence. The reviewer concludes with an invitation to read the │
# │ book, which could be interpreted as a positive recommendation, but given the context, it seems to be a          │
# │ constructive critique rather than an endorsement.                                                               │
# │                                                                                                                 │
# │ Correct classification: **Negative**                                                                            │
# │                                                                                                                 │
# │ **4. Generic Horror Movie (Positive → Negative)**                                                               │
# │ The review is overwhelmingly negative, calling the movie "derivative," "incoherent," and lacking any scares or  │
# │ tension. The tone remains consistently critical throughout, with no redeeming qualities mentioned. This         │
# │ misclassification likely resulted from the prompt's sensitivity to the reviewer's tone, which was initially     │
# │ unclear but ultimately confirmed as strongly negative.                                                          │
# │                                                                                                                 │
# │ Correct classification: **Negative**                                                                            │
# │                                                                                                                 │
# │ Strategies to improve the classification prompt:                                                                │
# │                                                                                                                 │
# │ 1. **Tone analysis**: Consider adding more nuanced tone-based features that can better capture the subtleties   │
# │ of sentiment in reviews. This might include tracking shifts in tone or sentiment throughout a review.           │
# │ 2. **Contextual understanding**: Improve the model's ability to understand context by incorporating techniques  │
# │ like coreference resolution, entity recognition, and discourse analysis. This will help the model better grasp  │
# │ the relationships between statements and identify when a positive or negative sentiment is actually             │
# │ constructive or critical.                                                                                       │
# │ 3. **Sentiment granulation**: Implement more granular sentiment classification (e.g., Strong Negative, Weak     │
# │ Positive, Constructive Criticism) to capture subtle differences in tone that might have led to                  │
# │ misclassifications.                                                                                             │
# │ 4. **Review-specific features**: Consider adding review-specific features like "movie-related criticism" or     │
# │ "book-related discussion" to help the model distinguish between reviews that discuss a movie and those that     │
# │ discuss a book.                                                                                                 │
# │                                                                                                                 │
# │ By implementing these strategies, we can reduce both false positives (e.g., Classifying Clonus as Positive) and │
# │ false negatives (e.g., Classifying Heart of Darkness as Negative for the movie), improving overall              │
# │ classification accuracy.                                                                                        │
# │                                                                                                                 │
# │         Your task is to provide a rewritten, production-ready version of the prompt that improves its accuracy. │
# │                                                                                                                 │
# │         IMPORTANT note: the prompt should not include any preamble or request for explanations, just the final  │
# │ prompt itself.                                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
